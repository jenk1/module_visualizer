# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
# create an empty graph with no nodes or edges

# %%
G = nx.Graph()

# %%
G

# %%
# add a node
G.add_node(1)

# %%
G

# %%
nx.draw(G)

# %%
G.add_nodes_from([3,4,2])

# %%
nx.draw(G)

# %%
G.add_edge(1, 2)

# %%
nx.draw(G)

# %%
G.add_node("spam")

# %%
nx.draw(G, with_labels=True)

# %%
G.add_edge(1, 4)

# %%
nx.draw(G, with_labels=True, node_size=800)
